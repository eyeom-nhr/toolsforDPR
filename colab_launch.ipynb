# %% [markdown]
# # Video World Cup Colab 임시 실행\n\nVercel 배포 전 테스트용입니다. Colab 런타임이 꺼지면 서버도 종료됩니다. GitHub에 올린 저장소 URL을 아래 셀에 넣어 실행하세요.\n

# %%
REPO_URL = 'https://github.com/YOUR_ID/YOUR_REPO.git'  # TODO: 본인 저장소로 변경\n!rm -rf video-worldcup-app\n!git clone $REPO_URL video-worldcup-app\n%cd video-worldcup-app\n!npm install\n

# %%
import subprocess, time\nfrom google.colab import output\n\nport = 5173\nproc = subprocess.Popen(['npm', 'run', 'dev', '--', '--host', '0.0.0.0', '--port', str(port)])\ntime.sleep(4)\noutput.serve_kernel_port_as_window(port, path='/')\n
